# %% [markdown]
# <a href="https://colab.research.google.com/github/aribiabdallah30-droid/mon_projet_colab/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/aribiabdallah30-droid/Mini-project-.git
# Out:
# Cloning into 'Mini-project-'...
# ...

# %%
# !git init -b main
# Out:
# Initialized empty Git repository in /content/.git/

# %%
# !git config user.name "AribiAbdallah"
# !git config user.email "aribiabdallah30@gmail.com"aribiabdallah30@gmail.com"
# Out:
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 2: syntax error: unexpected end of file

# %%
from getpass import getpass
import os
token = getpass('Entre ton GitHub token : ')
os.environ['GITHUB_TOKEN'] = token
# !git remote add origin https://github.com/aribiabdallah30-droid/Mini-project-.git
