# %% [markdown]
# <a href="https://colab.research.google.com/github/aribiabdallah30-droid/mon_projet_colab/blob/main/Untitled1_ipynb_abdou_aribi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p mon_projet
# %cd mon_projet
# !echo "Bonjour Git et GitHub depuis Colab" > texte.txt
# Out:
# /content/mon_projet

# %%
# !git init -b main
# Out:
# Initialized empty Git repository in /content/mon_projet/.git/

# %%
# !git config user.name "Abdallah"
# !git config user.email "aribiabdallah30@gmail.com"

# %%
# !git add .
# !git commit -m "Premier commit depuis Colab"
# Out:
# [main (root-commit) 66282d4] Premier commit depuis Colab
#  1 file changed, 1 insertion(+)
#  create mode 100644 texte.txt

# %%
from getpass import getpass
import os
token = getpass('Entre ton GitHub token : ')
os.environ['GITHUB_TOKEN'] = token
# !git remote add origin https://$GITHUB_TOKEN@github.com/aribiabdallah30-droid/mon_projet_colamon_projet_colab
# Out:
# Entre ton GitHub token : ··········
# error: remote origin already exists.

# %%
# !git push origin main --force
# Out:
# remote: Permission to aribiabdallah30-droid/mon_projet_colab.git denied to aribiabdallah30-droid.
# fatal: unable to access 'https://github.com/aribiabdallah30-droid/mon_projet_colab.git/': The requested URL returned error: 403
